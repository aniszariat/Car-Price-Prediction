# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
"""
Initial Data Understanding:

Data Loading and Inspection
Data Types
Missing Values
Duplicates
"""
# Out:
# '\nInitial Data Understanding:\n\nData Loading and Inspection\nData Types\nMissing Values\nDuplicates\n'

# %%
# Data Loading and Inspection
data = pd.read_csv("car_price_prediction.csv")
data.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# 1     Tiptronic          4x4  04-May        Left wheel   Black        8
# 2      Variator        Front  04-May  Right-hand drive   Black        2
# 3     Automatic          4x4  04-May        Left wheel   White        0
# 4     Automatic        Front  04-May        Left wheel  Silver        4

# %%
data.shape
# Out:
# (19237, 18)

# %%
# Data Types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
#  16  Color             19237 non-null  object
#  17  Airbags           19237 non-null  int64
# dtypes: float64(1), int64(4), object(13)
# memory usage: 2.6+ MB

# %%
# Missing Values
data.isna().sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %%
# Duplicates
data.duplicated().sum()
# Out:
# 313

# %%
# Remove duplicates
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (18924, 18)

# %%
"""
Basic Statistical Overview:

Summary Statistics (describe(), value_counts())
Zero and Constant Values
"""
# Out:
# '\nBasic Statistical Overview:\n\nSummary Statistics (describe(), value_counts())\nZero and Constant Values\n'

# %%
data.describe()
# Out:
#                  ID         Price    Prod. year     Cylinders       Airbags
# count  1.892400e+04  1.892400e+04  18924.000000  18924.000000  18924.000000
# mean   4.557538e+07  1.858744e+04   2010.914236      4.580216      6.568379
# std    9.375468e+05  1.921356e+05      5.665749      1.200223      4.322323
# min    2.074688e+07  1.000000e+00   1939.000000      1.000000      0.000000
# 25%    4.569501e+07  5.331000e+03   2009.000000      4.000000      4.000000
# 50%    4.577191e+07  1.317200e+04   2012.000000      4.000000      6.000000
# 75%    4.580174e+07  2.206300e+04   2015.000000      4.000000     12.000000
# max    4.581665e+07  2.630750e+07   2020.000000     16.000000     16.000000

# %%
data.select_dtypes(include='object').describe()
# Out:
#          Levy Manufacturer  Model Category Leather interior Fuel type  \
# count   18924        18924  18924    18924            18924     18924
# unique    559           65   1590       11                2         7
# top         -      HYUNDAI  Prius    Sedan              Yes    Petrol
# freq     5709         3729   1069     8600            13731      9944
#
#        Engine volume Mileage Gear box type Drive wheels   Doors       Wheel  \
# count          18924   18924         18924        18924   18924       18924
# unique           107    7687             4            3       3           2
# top                2    0 km     Automatic        Front  04-May  Left wheel
# freq            3856     714         13282        12695   18032       17471
#
#         Color
# count   18924
# unique     16
# top     Black
# freq     4944

# %%
data['Manufacturer'].unique()
# Out:
# array(['LEXUS', 'CHEVROLET', 'HONDA', 'FORD', 'HYUNDAI', 'TOYOTA',
#        'MERCEDES-BENZ', 'OPEL', 'PORSCHE', 'BMW', 'JEEP', 'VOLKSWAGEN',
#        'AUDI', 'RENAULT', 'NISSAN', 'SUBARU', 'DAEWOO', 'KIA',
#        'MITSUBISHI', 'SSANGYONG', 'MAZDA', 'GMC', 'FIAT', 'INFINITI',
#        'ALFA ROMEO', 'SUZUKI', 'ACURA', 'LINCOLN', 'VAZ', 'GAZ',
#        'CITROEN', 'LAND ROVER', 'MINI', 'DODGE', 'CHRYSLER', 'JAGUAR',
#        'ISUZU', 'SKODA', 'DAIHATSU', 'BUICK', 'TESLA', 'CADILLAC',
#        'PEUGEOT', 'BENTLEY', 'VOLVO', 'სხვა', 'HAVAL', 'HUMMER', 'SCION',
#        'UAZ', 'MERCURY', 'ZAZ', 'ROVER', 'SEAT', 'LANCIA', 'MOSKVICH',
#        'MASERATI', 'FERRARI', 'SAAB', 'LAMBORGHINI', 'ROLLS-ROYCE',
#        'PONTIAC', 'SATURN', 'ASTON MARTIN', 'GREATWALL'], dtype=object)

# %%
def top_and_bottom_combined(df, col, n=7):
    top_counts = df[col].value_counts().head(n)
    bottom_counts = df[col].value_counts().tail(n)
    
    combined = pd.concat([top_counts, bottom_counts], axis=0)
    return combined

for col in data.select_dtypes(include='object'):
    print(f'{col} value counts:')
    print(top_and_bottom_combined(data, col))
    print('30 Unique values:', data[col].unique()[:30])
    print('-------------------')
# Out:
# Levy value counts:
# Levy
# -       5709
# 765      482
# 891      453
# 639      403
# 640      398
# 781      294
# 1017     291
# 5666       1
# 2177       1
# 3156       1
# 2908       1
# 1279       1
# 1719       1
# 1901       1
# Name: count, dtype: int64
# 30 Unique values: ['1399' '1018' '-' '862' '446' '891' '761' '751' '394' '1053' '1055'
#  '1079' '810' '2386' '1850' '531' '586' '1249' '2455' '583' '1537' '1288'
#  '915' '1750' '707' '1077' '1486' '1091' '650' '382']
# -------------------
# Manufacturer value counts:
# Manufacturer
# HYUNDAI          3729
# TOYOTA           3606
# MERCEDES-BENZ    2043
# FORD             1088
# CHEVROLET        1047
# BMW              1036
# HONDA             960
# HAVAL               1
# LAMBORGHINI         1
# TESLA               1
# PONTIAC             1
# SATURN              1
# ASTON MARTIN        1
# GREATWALL           1
# Name: count, dtype: int64
# 30 Unique values: ['LEXUS' 'CHEVROLET' 'HONDA' 'FORD' 'HYUNDAI' 'TOYOTA' 'MERCEDES-BENZ'
#  'OPEL' 'PORSCHE' 'BMW' 'JEEP' 'VOLKSWAGEN' 'AUDI' 'RENAULT' 'NISSAN'
#  'SUBARU' 'DAEWOO' 'KIA' 'MITSUBISHI' 'SSANGYONG' 'MAZDA' 'GMC' 'FIAT'
#  'INFINITI' 'ALFA ROMEO' 'SUZUKI' 'ACURA' 'LINCOLN' 'VAZ' 'GAZ']
# -------------------
# Model value counts:
# Model
# Prius                     1069
# Sonata                    1067
# Camry                      929
# Elantra                    910
# E 350                      534
# Santa FE                   527
# FIT                        444
# GLK 300                      1
# Musa                         1
# 1500,1600 Schtufenheck       1
# E 420                        1
# C 250 luxury                 1
# Passat sport                 1
# Prius C aqua                 1
# Name: count, dtype: int64
# 30 Unique values: ['RX 450' 'Equinox' 'FIT' 'Escape' 'Santa FE' 'Prius' 'Sonata' 'Camry'
#  'RX 350' 'E 350' 'Transit' 'Vectra' 'CHR' 'Elantra' 'RX 400' 'E 220'
#  'GX 470' 'Highlander' 'Vito' 'Cayenne' 'X5' 'Grand Cherokee'
#  'CHR Limited' 'H1' 'Jetta' 'Tacoma' 'Prius C' 'Aqua' 'Escape Hybrid'
#  'Civic']
# -------------------
# Category value counts:
# Category
# Sedan          8600
# Jeep           5378
# Hatchback      2799
# Minivan         633
# Coupe           528
# Universal       361
# Microbus        299
# Coupe           528
# Universal       361
# Microbus        299
# Goods wagon     229
# Pickup           51
# Cabriolet        35
# Limousine        11
# Name: count, dtype: int64
# 30 Unique values: ['Jeep' 'Hatchback' 'Sedan' 'Microbus' 'Goods wagon' 'Universal' 'Coupe'
#  'Minivan' 'Cabriolet' 'Limousine' 'Pickup']
# -------------------
# Leather interior value counts:
# Leather interior
# Yes    13731
# No      5193
# Yes    13731
# No      5193
# Name: count, dtype: int64
# 30 Unique values: ['Yes' 'No']
# -------------------
# Fuel type value counts:
# Fuel type
# Petrol            9944
# Diesel            4001
# Hybrid            3539
# LPG                885
# CNG                469
# Plug-in Hybrid      85
# Hydrogen             1
# Petrol            9944
# Diesel            4001
# Hybrid            3539
# LPG                885
# CNG                469
# Plug-in Hybrid      85
# Hydrogen             1
# Name: count, dtype: int64
# 30 Unique values: ['Hybrid' 'Petrol' 'Diesel' 'CNG' 'Plug-in Hybrid' 'LPG' 'Hydrogen']
# -------------------
# Engine volume value counts:
# Engine volume
# 2            3856
# 2.5          2246
# 1.8          1743
# 1.6          1446
# 1.5          1289
# 3.5          1182
# 2.4           977
# 0.2 Turbo       1
# 5.7 Turbo       1
# 6.8             1
# 6.7             1
# 3.1             1
# 0.8 Turbo       1
# 1.1 Turbo       1
# Name: count, dtype: int64
# 30 Unique values: ['3.5' '3' '1.3' '2.5' '2' '1.8' '2.4' '4' '1.6' '3.3' '2.0 Turbo'
#  '2.2 Turbo' '4.7' '1.5' '4.4' '3.0 Turbo' '1.4 Turbo' '3.6' '2.3'
#  '1.5 Turbo' '1.6 Turbo' '2.2' '2.3 Turbo' '1.4' '5.5' '2.8 Turbo' '3.2'
#  '3.8' '4.6' '1.2']
# -------------------
# Mileage value counts:
# Mileage
# 0 km         714
# 200000 km    181
# 150000 km    159
# 160000 km    120
# 180000 km    117
# 100000 km    105
# 1000 km      100
# 133016 km      1
# 78462 km       1
# 100563 km      1
# 354300 km      1
# 21178 km       1
# 110539 km      1
# 186923 km      1
# Name: count, dtype: int64
# 30 Unique values: ['186005 km' '192000 km' '200000 km' '168966 km' '91901 km' '160931 km'
#  '258909 km' '216118 km' '398069 km' '128500 km' '184467 km' '0 km'
#  '350000 km' '138038 km' '76000 km' '74146 km' '121840 km' '54317 km'
#  '295059 km' '364523 km' '112645 km' '187000 km' '39709 km' '230000 km'
#  '210000 km' '169000 km' '158787 km' '420550 km' '180000 km' '175056 km']
# -------------------
# Gear box type value counts:
# Gear box type
# Automatic    13282
# Tiptronic     3065
# Manual        1844
# Variator       733
# Automatic    13282
# Tiptronic     3065
# Manual        1844
# Variator       733
# Name: count, dtype: int64
# 30 Unique values: ['Automatic' 'Tiptronic' 'Variator' 'Manual']
# -------------------
# Drive wheels value counts:
# Drive wheels
# Front    12695
# 4x4       3969
# Rear      2260
# Front    12695
# 4x4       3969
# Rear      2260
# Name: count, dtype: int64
# 30 Unique values: ['4x4' 'Front' 'Rear']
# -------------------
# Doors value counts:
# Doors
# 04-May    18032
# 02-Mar      768
# >5          124
# 04-May    18032
# 02-Mar      768
# >5          124
# Name: count, dtype: int64
# 30 Unique values: ['04-May' '02-Mar' '>5']
# -------------------
# Wheel value counts:
# Wheel
# Left wheel          17471
# Right-hand drive     1453
# Left wheel          17471
# Right-hand drive     1453
# Name: count, dtype: int64
# 30 Unique values: ['Left wheel' 'Right-hand drive']
# -------------------
# Color value counts:
# Color
# Black            4944
# White            4407
# Silver           3729
# Grey             2343
# Blue             1376
# Red               622
# Green             321
# Carnelian red     177
# Golden            143
# Beige             134
# Sky blue          122
# Yellow            105
# Purple             39
# Pink               25
# Name: count, dtype: int64
# 30 Unique values: ['Silver' 'Black' 'White' 'Grey' 'Blue' 'Green' 'Red' 'Sky blue' 'Orange'
#  'Yellow' 'Brown' 'Golden' 'Beige' 'Carnelian red' 'Purple' 'Pink']
# -------------------

# %%
# fix the problem 
# replace - with 0
# data['Levy'].replace({'-':0},inplace=True)
data.replace({'Levy':{'-':0}},inplace=True)
data['Levy']=pd.to_numeric(data['Levy'])

# %%
data.Levy
# Out:
# 0        1399
# 1        1018
# 2           0
# 3         862
# 4         446
#          ...
# 19232       0
# 19233     831
# 19234     836
# 19235    1288
# 19236     753
# Name: Levy, Length: 18924, dtype: int64

# %%
data['Engine volume'] = data['Engine volume'].str.replace("Turbo","")
data['Engine volume'] = pd.to_numeric(data['Engine volume'])

# %%
data['Engine volume']
# Out:
# 0        3.5
# 1        3.0
# 2        1.3
# 3        2.5
# 4        1.3
#         ...
# 19232    2.0
# 19233    2.4
# 19234    2.0
# 19235    2.0
# 19236    2.4
# Name: Engine volume, Length: 18924, dtype: float64

# %%
data['Mileage'] = data['Mileage'].str.replace('km','')
data['Mileage'] = pd.to_numeric(data['Mileage'])

# %%
data['Mileage']
# Out:
# 0        186005
# 1        192000
# 2        200000
# 3        168966
# 4         91901
#           ...
# 19232    300000
# 19233    161600
# 19234    116365
# 19235     51258
# 19236    186923
# Name: Mileage, Length: 18924, dtype: int64

# %%
data.drop(['Doors'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18924 entries, 0 to 19236
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18924 non-null  int64
#  1   Price             18924 non-null  int64
#  2   Levy              18924 non-null  int64
#  3   Manufacturer      18924 non-null  object
#  4   Model             18924 non-null  object
#  5   Prod. year        18924 non-null  int64
#  6   Category          18924 non-null  object
#  7   Leather interior  18924 non-null  object
#  8   Fuel type         18924 non-null  object
#  9   Engine volume     18924 non-null  float64
#  10  Mileage           18924 non-null  int64
#  11  Cylinders         18924 non-null  float64
#  12  Gear box type     18924 non-null  object
#  13  Drive wheels      18924 non-null  object
#  14  Wheel             18924 non-null  object
#  15  Color             18924 non-null  object
#  16  Airbags           18924 non-null  int64
# dtypes: float64(2), int64(6), object(9)
# memory usage: 2.6+ MB

# %%
"""
Distribution of Variables

Numerical Features (histograms, KDE)
Categorical Features (bar plots, check imbalancement)
Outlier detection
"""
# Out:
# '\nDistribution of Variables\n\nNumerical Features (histograms, KDE)\nCategorical Features (bar plots, check imbalancement)\nOutlier detection\n'

# %%
for col in data.select_dtypes('number').columns:
    sns.kdeplot(data[col])
    plt.show()

# %%
sns.kdeplot(np.log(data['Mileage']))
plt.show()
# Out:
# C:\Users\zaria\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
"""
Correlations

Numerical Correlations (corr())
Categorical Correlations
"""
# Out:
# '\nCorrelations\n\nNumerical Correlations (corr())\nCategorical Correlations\n'

# %%
sns.heatmap(data.corr(numeric_only=True), annot=True)
plt.show()

# %%
"""
Feature Interactions
Scatter Plots
"""
# Out:
# '\nFeature Interactions\nScatter Plots\n'

# %%
sns.pairplot(data[:100])

# %%
sns.boxplot(data['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
data[data['Price']>5e5]
# Out:
#              ID     Price  Levy   Manufacturer           Model  Prod. year  \
# 1225   45795524    627220     0  MERCEDES-BENZ  G 65 AMG 63AMG        2020
# 8541   45761204    872946  2067    LAMBORGHINI            Urus        2019
# 16983  45812886  26307500     0           OPEL           Combo        1999
#
#           Category Leather interior Fuel type  Engine volume  Mileage  \
# 1225          Jeep              Yes    Petrol            6.3        0
# 8541     Universal              Yes    Petrol            4.0     2531
# 16983  Goods wagon               No    Diesel            1.7    99999
#
#        Cylinders Gear box type Drive wheels       Wheel  Color  Airbags
# 1225         8.0     Tiptronic          4x4  Left wheel  Black       12
# 8541         8.0     Tiptronic          4x4  Left wheel  Black        0
# 16983        4.0        Manual        Front  Left wheel   Blue        0

# %%
sns.boxplot(data['Levy'])
# Out:
# <Axes: ylabel='Levy'>

# %%
sns.boxplot(data['Mileage'])
# Out:
# <Axes: ylabel='Mileage'>

# %%
def clean_outliers(df, col):
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    
    df_no_outliers = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
    return df_no_outliers

# %%
data = clean_outliers(data, 'Price')
data = clean_outliers(data, 'Mileage')
data = clean_outliers(data, 'Levy')
